# %% [markdown]
# # Phi-3 LoRA Text-to-SQL (Unsloth)
#
# Fine-tune `unsloth/Phi-3-mini-4k-instruct` with LoRA/QLoRA to convert natural language questions into SQL.
#
# **Runtime:** GPU recommended (Colab T4 works).

# %%
# Install Unsloth (Colab / CUDA). Adjust CUDA tag for your environment.
# !pip install -q --upgrade pip
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
# !pip install -q datasets transformers

# %%
# If running from the repo root locally:
# %cd /path/to/phi3-text-to-sql
# !python scripts/prepare_dataset.py
# !python scripts/train_lora.py --epochs 3 --batch-size 2 --grad-accum 4

# %%
# !python scripts/infer.py --question "What is the Enterprise list price for Cloud Shield (CS-ENT)?"
# !python scripts/evaluate.py --limit 5
